# %% [markdown]
# # RetailPulse Project Validation
#
# Purpose:
# Validate all project outputs.

# %%
# %sql

SHOW TABLES IN workspace.retailpulse;

# %%
# %sql
SELECT *
FROM workspace.retailpulse.gold_region_revenue;

# %%
# %sql
SELECT *
FROM workspace.retailpulse.gold_category_revenue;

# %%
# %sql
SELECT *
FROM workspace.retailpulse.gold_top_customers;

# %%
# %sql
DESCRIBE HISTORY workspace.retailpulse.bronze_sales;
